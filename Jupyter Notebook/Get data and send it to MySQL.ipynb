# %% [markdown]
# ## Import the data to send it to MySQL

# %%
import pandas as pd

# %%
df = pd.read_excel(r"E:\ALL\Full_Projects\3)_BlinkIT_Grocery_Project\data\BlinkIT Grocery Data.xlsx")

# %%
print(len(df))
# Out:
# 8523

# %% [markdown]
# -------------------------------------

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://root:mysql%40150476@localhost/BlinkIT_sales_project")

# %%
df.to_sql("sales_raw", con=engine, if_exists="replace", index=False)
# Out:
# 8523
